# %%
import pandas as pd
import matplotlib.pyplot as plt
from models import SIR_V, SIRV
from models_2 import SIR_V_CHOICE

# %%
param = {
    's': 0.999,
    'i': 0.001,
    'r': 0,
    'r_coef': 3,
    'c_i': 10,
    'c_v': 9,
    'treshhold': 0.0005,
    'smoothenes': 0.001,
    'max_iter': 100000,
}
model_object = SIR_V_CHOICE(*param.values())

# %%
model_object.model_info
# Out:
#        timestamp         s         i         r    v
# 0              0  0.899000  0.001000  0.000000  0.1
# 1              1  0.898997  0.001002  0.000001  0.1
# 2              2  0.898995  0.001003  0.000002  0.1
# 3              3  0.898992  0.001005  0.000003  0.1
# 4              4  0.898989  0.001007  0.000004  0.1
# ...          ...       ...       ...       ...  ...
# 13388      13388  0.076192  0.000502  0.823306  0.1
# 13389      13389  0.076192  0.000501  0.823307  0.1
# 13390      13390  0.076192  0.000501  0.823307  0.1
# 13391      13391  0.076192  0.000500  0.823308  0.1
# 13392      13392  0.076192  0.000500  0.823308  0.1
#
# [13393 rows x 5 columns]

# %%
model_object.diplay_plots()

# %%
model_object.analyze_equilibria()
# Out:
# ...
# АНАЛИЗ РАВНОВЕСИЙ МОДЕЛИ ВАКЦИНАЦИИ
# ...
#
# ПАРАМЕТРЫ МОДЕЛИ:
# R₀: 3.00
# c_v: 9.0
# c_i: 10.0
# Порог коллективного иммунитета: 0.667
#
# РАВНОВЕСИЕ НЭША:
# v = 0.1000
# r = 0.8240
# Издержки = 9.1403
# Тип: mixed equilibrium
# Проверка условия: 8.240 vs 9.0
#
# ПАРЕТО-ОПТИМУМ:
# v = 0.6735
# r = 0.0000
# Издержки = 6.0612
#
# СРАВНИТЕЛЬНЫЙ АНАЛИЗ:
# Разница издержек: 3.0791
# Эффективность: Неэффективно
# Причина неэффективности: недостаточная вакцинация
# Дефицит вакцинации: 0.5735
# ...
# {'parameters': {'R0': 3.0, 'c_v': 9.0, 'c_i': 10.0, 'herd_threshold': 0.6667},
#  'nash_equilibrium': {'vaccination_rate': 0.1,
#   'infection_prob': 0.824,
#   'social_cost': 9.1403,
#   'equilibrium_type': 'mixed equilibrium',
#   'condition_check': '8.240 vs 9.0'},
#  'pareto_optimum': {'vaccination_rate': 0.6735,
#   'infection_prob': 0.0,
#   'social_cost': 6.0612},
#  'efficiency_analysis': {'cost_difference': 3.0791,
#   'is_efficient': False,
#   'efficiency_status': 'Неэффективно',
# ...
